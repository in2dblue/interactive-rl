# %%
import pandas     as pd
import numpy      as np
#import matplotlib.pyplot as plt
from matplotlib import pyplot, pylab

# %%
data1 = pd.read_csv('progress10-128.csv')
data2 = pd.read_csv('progress100-128.csv')
data3 = pd.read_csv('progress10k-128.csv')

data3.head()
# Out:
#    epoch  stats_g/mean  stats_g/std  stats_o/mean  stats_o/std  test/episode  \
# 0      0      0.868131     0.099361      0.207402     0.032050          10.0
# 1      1      0.868096     0.099364      0.207398     0.032076          20.0
# 2      2      0.868033     0.099371      0.207386     0.033217          30.0
# 3      3      0.868003     0.099389      0.207388     0.034213          40.0
# 4      4      0.867967     0.099399      0.207378     0.035121          50.0
#
#    test/mean_Q  test/success_rate  train/episode  train/success_rate
# 0    -1.661765                0.0           20.0                0.05
# 1    -2.414706                0.0           40.0                0.05
# 2    -3.651803                0.0           60.0                0.05
# 3    -4.078525                0.2           80.0                0.10
# 4    -4.987140                0.1          100.0                0.05

# %%
pyplot.figure(figsize=(15,5))
for data in [data1, data2, data3]:
    pyplot.plot(data['epoch'], data['test/mean_Q'], label='sample')
pylab.xlabel('Epoch')
pylab.ylabel('Mean Q value')
#pyplot.fill_between(color=color)
#pyplot.xlim(0,6)
pyplot.title('Training results comparison for Fetch-PickAndPlace')
L=pyplot.legend()

L.get_texts()[0].set_text('10-128')
L.get_texts()[1].set_text('100-128')
L.get_texts()[2].set_text('10k-128')
pyplot.savefig('10_100_10k-128QValue.png')

# %%
pyplot.figure(figsize=(15,5))
for data in [data1, data2, data3]:
    pyplot.plot(data['epoch'], data['test/success_rate'], label='sample')
pylab.xlabel('Epoch')
pylab.ylabel('Success Rate')
#pyplot.fill_between(color=color)
#pyplot.xlim(0,6)
pyplot.title('Training results comparison for Fetch-PickAndPlace')
L=pyplot.legend()

L.get_texts()[0].set_text('10-128')
L.get_texts()[1].set_text('100-128')
L.get_texts()[2].set_text('10k-128')
pyplot.savefig('10_100_10k-128SuccessRate.png')

# %%
data1.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.843787
# stats_g/std              0.112475
# stats_o/mean             0.203375
# stats_o/std              0.099920
# test/episode          1005.000000
# test/mean_Q            -14.939220
# test/success_rate        0.151000
# train/episode         2010.000000
# train/success_rate       0.116000
# dtype: float64

# %%
data2.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.841163
# stats_g/std              0.135191
# stats_o/mean             0.204081
# stats_o/std              0.125125
# test/episode          1005.000000
# test/mean_Q             -6.565852
# test/success_rate        0.562000
# train/episode         2010.000000
# train/success_rate       0.313750
# dtype: float64

# %%
data3.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.864861
# stats_g/std              0.106185
# stats_o/mean             0.207468
# stats_o/std              0.067156
# test/episode          1005.000000
# test/mean_Q             -3.852670
# test/success_rate        0.766000
# train/episode         2010.000000
# train/success_rate       0.430250
# dtype: float64
