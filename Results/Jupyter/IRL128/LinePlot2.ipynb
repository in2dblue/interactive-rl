# %%
import pandas     as pd
import numpy      as np
#import matplotlib.pyplot as plt
from matplotlib import pyplot, pylab

# %%
data1 = pd.read_csv('progress100-128.csv')
data2 = pd.read_csv('progress250-128.csv')
data3 = pd.read_csv('progress500-128.csv')
data4 = pd.read_csv('progress1k-128.csv')
data5 = pd.read_csv('progress2_5k-128.csv')
data6 = pd.read_csv('progress5k-128.csv')
data7 = pd.read_csv('progress7_5k-128.csv')
data8 = pd.read_csv('progress10k-128.csv')

data4.head()
# Out:
#    epoch  stats_g/mean  stats_g/std  stats_o/mean  stats_o/std  test/episode  \
# 0      0      0.869178     0.100587      0.207922     0.037288          10.0
# 1      1      0.868833     0.101036      0.207939     0.040817          20.0
# 2      2      0.868461     0.101163      0.207946     0.041339          30.0
# 3      3      0.868105     0.101204      0.207973     0.042894          40.0
# 4      4      0.867543     0.101318      0.207800     0.044590          50.0
#
#    test/mean_Q  test/success_rate  train/episode  train/success_rate
# 0    -1.459162                0.3           20.0                0.00
# 1    -2.410076                0.2           40.0                0.05
# 2    -3.233593                0.1           60.0                0.10
# 3    -2.783176                0.7           80.0                0.05
# 4    -3.549407                0.4          100.0                0.05

# %%
pyplot.figure(figsize=(25,11))
for data in [data1, data2, data3, data4, data5, data6, data7, data8]:
    pyplot.plot(data['epoch'], data['test/mean_Q'])
pylab.xlabel('Epoch')
pylab.ylabel('Mean Q value')
#pyplot.fill_between(color=color)
#pyplot.xlim(0,6)
pyplot.title('Training results comparison for Fetch-PickAndPlace')
L=pyplot.legend()

L.get_texts()[0].set_text('100-128')
L.get_texts()[1].set_text('250-128')
L.get_texts()[2].set_text('500-128')
L.get_texts()[3].set_text('1k-128')
L.get_texts()[4].set_text('2.5k-128')
L.get_texts()[5].set_text('5k-128')
L.get_texts()[6].set_text('7.5k-128')
L.get_texts()[7].set_text('10k-128')
# L.get_texts()[4].set_text('6 Layers')

# pyplot.savefig('FetchPickPlaceNeuronMean.jpg')

# %%
pyplot.figure(figsize=(25,11))
for data in [data1, data2, data3, data4, data5, data6, data7, data8]:
    pyplot.plot(data['epoch'], data['test/success_rate'])
pylab.xlabel('Epoch')
pylab.ylabel('Success Rate')
#pyplot.fill_between(color=color)
#pyplot.xlim(0,6)
pyplot.title('Training results comparison for Fetch-PickAndPlace')
L=pyplot.legend()

L.get_texts()[0].set_text('100-128')
L.get_texts()[1].set_text('250-128')
L.get_texts()[2].set_text('500-128')
L.get_texts()[3].set_text('1k-128')
L.get_texts()[4].set_text('2.5k-128')
L.get_texts()[5].set_text('5k-128')
L.get_texts()[6].set_text('7.5k-128')
L.get_texts()[7].set_text('10k-128')

# %%
# 100
data1.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.841163
# stats_g/std              0.135191
# stats_o/mean             0.204081
# stats_o/std              0.125125
# test/episode          1005.000000
# test/mean_Q             -6.565852
# test/success_rate        0.562000
# train/episode         2010.000000
# train/success_rate       0.313750
# dtype: float64

# %%
# 250
data2.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.844835
# stats_g/std              0.134715
# stats_o/mean             0.208104
# stats_o/std              0.123695
# test/episode          1005.000000
# test/mean_Q             -5.692466
# test/success_rate        0.640000
# train/episode         2010.000000
# train/success_rate       0.362250
# dtype: float64

# %%
# 500
data3.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.847913
# stats_g/std              0.131615
# stats_o/mean             0.201697
# stats_o/std              0.120039
# test/episode          1005.000000
# test/mean_Q             -6.208528
# test/success_rate        0.596000
# train/episode         2010.000000
# train/success_rate       0.308250
# dtype: float64

# %%
# 1000
data4.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.855478
# stats_g/std              0.122356
# stats_o/mean             0.205536
# stats_o/std              0.109197
# test/episode          1005.000000
# test/mean_Q             -5.061645
# test/success_rate        0.670500
# train/episode         2010.000000
# train/success_rate       0.365000
# dtype: float64

# %%
# 2500
data5.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.858458
# stats_g/std              0.116665
# stats_o/mean             0.206488
# stats_o/std              0.093257
# test/episode          1005.000000
# test/mean_Q             -5.261094
# test/success_rate        0.635000
# train/episode         2010.000000
# train/success_rate       0.359250
# dtype: float64

# %%
# 5000
data6.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.860667
# stats_g/std              0.110695
# stats_o/mean             0.206321
# stats_o/std              0.078922
# test/episode          1005.000000
# test/mean_Q             -5.103214
# test/success_rate        0.673500
# train/episode         2010.000000
# train/success_rate       0.354250
# dtype: float64

# %%
# 7500
data7.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.863223
# stats_g/std              0.107409
# stats_o/mean             0.208033
# stats_o/std              0.072244
# test/episode          1005.000000
# test/mean_Q             -5.331774
# test/success_rate        0.638500
# train/episode         2010.000000
# train/success_rate       0.354500
# dtype: float64

# %%
# 10000
data8.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.864861
# stats_g/std              0.106185
# stats_o/mean             0.207468
# stats_o/std              0.067156
# test/episode          1005.000000
# test/mean_Q             -3.852670
# test/success_rate        0.766000
# train/episode         2010.000000
# train/success_rate       0.430250
# dtype: float64
