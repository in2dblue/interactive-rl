# %%
import pandas     as pd
import numpy      as np
#import matplotlib.pyplot as plt
from matplotlib import pyplot, pylab

# %%
# data1 = pd.read_csv('progress100-128.csv')
data2 = pd.read_csv('progress250-512.csv')
data3 = pd.read_csv('progress500-512.csv')
data4 = pd.read_csv('progress1k-512.csv')
data5 = pd.read_csv('progress2_5k-512.csv')
data6 = pd.read_csv('progress5k-512.csv')
data7 = pd.read_csv('progress7_5k-512.csv')
data8 = pd.read_csv('progress10k-512.csv')

data4.head()
# Out:
#    epoch  stats_g/mean  stats_g/std  stats_o/mean  stats_o/std  test/episode  \
# 0      0      0.868946     0.100640      0.207579     0.035973          10.0
# 1      1      0.868755     0.100739      0.207668     0.039732          20.0
# 2      2      0.868582     0.101695      0.207797     0.042785          30.0
# 3      3      0.867978     0.102380      0.207892     0.045960          40.0
# 4      4      0.867638     0.103095      0.207772     0.046718          50.0
#
#    test/mean_Q  test/success_rate  train/episode  train/success_rate
# 0    -1.852433                0.3           20.0                0.05
# 1    -2.751079                0.1           40.0                0.05
# 2    -3.370870                0.2           60.0                0.05
# 3    -3.820258                0.5           80.0                0.00
# 4    -4.334949                0.3          100.0                0.00

# %%
pyplot.figure(figsize=(25,11))
for data in [data2, data3, data4, data5, data6, data7, data8]:
    pyplot.plot(data['epoch'], data['test/mean_Q'])
pylab.xlabel('Epoch')
pylab.ylabel('Mean Q value')
#pyplot.fill_between(color=color)
#pyplot.xlim(0,6)
pyplot.title('Training results comparison for Fetch-PickAndPlace')
L=pyplot.legend()

# L.get_texts()[0].set_text('100-128')
L.get_texts()[0].set_text('250-512')
L.get_texts()[1].set_text('500-512')
L.get_texts()[2].set_text('1k-512')
L.get_texts()[3].set_text('2.5k-512')
L.get_texts()[4].set_text('5k-512')
L.get_texts()[5].set_text('7.5k-512')
L.get_texts()[6].set_text('10k-512')
# L.get_texts()[4].set_text('6 Layers')

# pyplot.savefig('FetchPickPlaceNeuronMean.jpg')

# %%
pyplot.figure(figsize=(25,11))
for data in [data2, data3, data4, data5, data6, data7, data8]:
    pyplot.plot(data['epoch'], data['test/success_rate'])
pylab.xlabel('Epoch')
pylab.ylabel('Success Rate')
#pyplot.fill_between(color=color)
#pyplot.xlim(0,6)
pyplot.title('Training results comparison for Fetch-PickAndPlace')
L=pyplot.legend()

# L.get_texts()[0].set_text('100-128')
L.get_texts()[0].set_text('250-512')
L.get_texts()[1].set_text('500-512')
L.get_texts()[2].set_text('1k-512')
L.get_texts()[3].set_text('2.5k-512')
L.get_texts()[4].set_text('5k-512')
L.get_texts()[5].set_text('7.5k-512')
L.get_texts()[6].set_text('10k-512')

# %%
# data1.mean()

# %%
# 250
data2.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.848245
# stats_g/std              0.133748
# stats_o/mean             0.203478
# stats_o/std              0.122704
# test/episode          1005.000000
# test/mean_Q             -4.800211
# test/success_rate        0.758000
# train/episode         2010.000000
# train/success_rate       0.412500
# dtype: float64

# %%
# 500
data3.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.850668
# stats_g/std              0.122757
# stats_o/mean             0.208185
# stats_o/std              0.110532
# test/episode          1005.000000
# test/mean_Q             -3.493371
# test/success_rate        0.835000
# train/episode         2010.000000
# train/success_rate       0.465000
# dtype: float64

# %%
# 1000
data4.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.856387
# stats_g/std              0.123035
# stats_o/mean             0.207688
# stats_o/std              0.109478
# test/episode          1005.000000
# test/mean_Q             -4.603284
# test/success_rate        0.750000
# train/episode         2010.000000
# train/success_rate       0.425750
# dtype: float64

# %%
# 2500
data5.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.860517
# stats_g/std              0.113113
# stats_o/mean             0.207001
# stats_o/std              0.085469
# test/episode          1005.000000
# test/mean_Q             -3.546642
# test/success_rate        0.816500
# train/episode         2010.000000
# train/success_rate       0.469500
# dtype: float64

# %%
# 5000
data6.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.861738
# stats_g/std              0.110775
# stats_o/mean             0.206665
# stats_o/std              0.077695
# test/episode          1005.000000
# test/mean_Q             -4.481868
# test/success_rate        0.780500
# train/episode         2010.000000
# train/success_rate       0.442000
# dtype: float64

# %%
# 7500
data7.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.863701
# stats_g/std              0.107018
# stats_o/mean             0.206929
# stats_o/std              0.070887
# test/episode          1005.000000
# test/mean_Q             -3.848830
# test/success_rate        0.808000
# train/episode         2010.000000
# train/success_rate       0.454000
# dtype: float64

# %%
# 10000
data8.mean()
# Out:
# epoch                   99.500000
# stats_g/mean             0.865110
# stats_g/std              0.105586
# stats_o/mean             0.207368
# stats_o/std              0.064627
# test/episode          1005.000000
# test/mean_Q             -3.775932
# test/success_rate        0.818500
# train/episode         2010.000000
# train/success_rate       0.469250
# dtype: float64
