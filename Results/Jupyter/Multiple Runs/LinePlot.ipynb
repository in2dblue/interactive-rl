# %%
import pandas     as pd
import numpy      as np
#import matplotlib.pyplot as plt
from matplotlib import pyplot, pylab

# %%
data1 = pd.read_csv('progress10-128.csv')
data2 = pd.read_csv('progress100-128.csv')
data3 = pd.read_csv('progress10k-128.csv')

data3.head()
# Out:
#    Unnamed: 0  epoch  stats_g/mean  stats_g/std  stats_o/mean  stats_o/std  \
# 0           0    0.0      0.868082     0.099383      0.207392     0.032616
# 1           1    1.0      0.868034     0.099400      0.207382     0.032759
# 2           2    2.0      0.867985     0.099406      0.207367     0.033597
# 3           3    3.0      0.867953     0.099428      0.207365     0.034315
# 4           4    4.0      0.867916     0.099434      0.207351     0.035020
#
#    test/episode  test/mean_Q  test/success_rate  train/episode  \
# 0          10.0    -1.606768              0.025           20.0
# 1          20.0    -2.415649              0.075           40.0
# 2          30.0    -3.218902              0.125           60.0
# 3          40.0    -3.935441              0.175           80.0
# 4          50.0    -3.993448              0.375          100.0
#
#    train/success_rate
# 0              0.0500
# 1              0.0750
# 2              0.0250
# 3              0.0625
# 4              0.0875

# %%
pyplot.figure(figsize=(15,5))
for data in [data1, data2, data3]:
    pyplot.plot(data['epoch'], data['test/mean_Q'], label='sample')
pylab.xlabel('Epoch')
pylab.ylabel('Mean Q value')
#pyplot.fill_between(color=color)
#pyplot.xlim(0,6)
pyplot.title('Training results comparison for Fetch-PickAndPlace')
L=pyplot.legend()

L.get_texts()[0].set_text('10-128')
L.get_texts()[1].set_text('100-128')
L.get_texts()[2].set_text('10k-128')
pyplot.savefig('10_100_10k-128QValue.png')

# %%
pyplot.figure(figsize=(15,5))
for data in [data1, data2, data3]:
    pyplot.plot(data['epoch'], data['test/success_rate'], label='sample')
pylab.xlabel('Epoch')
pylab.ylabel('Success Rate')
#pyplot.fill_between(color=color)
#pyplot.xlim(0,6)
pyplot.title('Training results comparison for Fetch-PickAndPlace')
L=pyplot.legend()

L.get_texts()[0].set_text('10-128')
L.get_texts()[1].set_text('100-128')
L.get_texts()[2].set_text('10k-128')
pyplot.savefig('10_100_10k-128SuccessRate.png')

# %%
data1.mean()
# Out:
# Unnamed: 0              99.500000
# epoch                   99.500000
# stats_g/mean             0.844397
# stats_g/std              0.114840
# stats_o/mean             0.204396
# stats_o/std              0.104055
# test/episode          1005.000000
# test/mean_Q            -14.244173
# test/success_rate        0.168500
# train/episode         2010.000000
# train/success_rate       0.127375
# dtype: float64

# %%
data2.mean()
# Out:
# Unnamed: 0              99.500000
# epoch                   99.500000
# stats_g/mean             0.843603
# stats_g/std              0.131115
# stats_o/mean             0.204583
# stats_o/std              0.127069
# test/episode          1005.000000
# test/mean_Q             -6.908270
# test/success_rate        0.531000
# train/episode         2010.000000
# train/success_rate       0.301563
# dtype: float64

# %%
data3.mean()
# Out:
# Unnamed: 0              99.500000
# epoch                   99.500000
# stats_g/mean             0.864890
# stats_g/std              0.106778
# stats_o/mean             0.206956
# stats_o/std              0.068173
# test/episode          1005.000000
# test/mean_Q             -4.354161
# test/success_rate        0.721500
# train/episode         2010.000000
# train/success_rate       0.408062
# dtype: float64
