# %%
import pandas     as pd
import numpy      as np
#import matplotlib.pyplot as plt
from matplotlib import pyplot, pylab

# %%
data1 = pd.read_csv('progress10k-512.csv')
data2 = pd.read_csv('progress10k-896-128.csv')

data2.head()
# Out:
#    Unnamed: 0  epoch  stats_g/mean  stats_g/std  stats_o/mean  stats_o/std  \
# 0           0    0.0      0.868056     0.099402      0.207400     0.032360
# 1           1    1.0      0.868025     0.099408      0.207388     0.033120
# 2           2    2.0      0.867980     0.099487      0.207387     0.034251
# 3           3    3.0      0.867925     0.099504      0.207380     0.034983
# 4           4    4.0      0.867878     0.099557      0.207388     0.035795
#
#    test/episode  test/mean_Q  test/success_rate  train/episode  \
# 0          10.0    -1.702940           0.100000           20.0
# 1          20.0    -2.352248           0.266667           40.0
# 2          30.0    -2.895609           0.266667           60.0
# 3          40.0    -3.076689           0.500000           80.0
# 4          50.0    -3.589419           0.500000          100.0
#
#    train/success_rate
# 0            0.033333
# 1            0.000000
# 2            0.033333
# 3            0.150000
# 4            0.033333

# %%
pyplot.figure(figsize=(15,5))
for data in [data1, data2]:
    pyplot.plot(data['epoch'], data['test/mean_Q'], label='sample')
pylab.xlabel('Epoch')
pylab.ylabel('Mean Q value')
#pyplot.fill_between(color=color)
#pyplot.xlim(0,6)
pyplot.title('Training results comparison for Fetch-PickAndPlace')
L=pyplot.legend()

L.get_texts()[0].set_text('10k-512')
L.get_texts()[1].set_text('10k-896-128')
# L.get_texts()[2].set_text('2.5k-512')
# L.get_texts()[3].set_text('5k-512')
# L.get_texts()[4].set_text('7.5k-512')
# L.get_texts()[5].set_text('10k-512')

# pyplot.savefig('FetchPickPlaceNeuronMean.jpg')
pyplot.savefig('10k_512vs896-128QValue.png')

# %%
pyplot.figure(figsize=(15,5))
for data in [data1, data2]:
    pyplot.plot(data['epoch'], data['test/success_rate'], label='sample')
pylab.xlabel('Epoch')
pylab.ylabel('Success Rate')
#pyplot.fill_between(color=color)
#pyplot.xlim(0,6)
pyplot.title('Training results comparison for Fetch-PickAndPlace')
L=pyplot.legend()

L.get_texts()[0].set_text('10k-512')
L.get_texts()[1].set_text('10k-896-128')
# L.get_texts()[2].set_text('2.5k-512')
# L.get_texts()[3].set_text('5k-512')
# L.get_texts()[4].set_text('7.5k-512')
# L.get_texts()[5].set_text('10k-512')
pyplot.savefig('10k_512vs896-128SuccessRate.png')

# %%
data1.mean()
# Out:
# Unnamed: 0              99.500000
# epoch                   99.500000
# stats_g/mean             0.865253
# stats_g/std              0.105645
# stats_o/mean             0.207588
# stats_o/std              0.064946
# test/episode          1005.000000
# test/mean_Q             -3.796188
# test/success_rate        0.816750
# train/episode         2010.000000
# train/success_rate       0.468125
# dtype: float64

# %%
data2.mean()
# Out:
# Unnamed: 0             99.500000
# epoch                  99.500000
# stats_g/mean            0.866649
# stats_g/std             0.102662
# stats_o/mean            0.207292
# stats_o/std             0.052941
# test/episode          205.000000
# test/mean_Q            -7.357791
# test/success_rate       0.473833
# train/episode         410.000000
# train/success_rate      0.164417
# dtype: float64
